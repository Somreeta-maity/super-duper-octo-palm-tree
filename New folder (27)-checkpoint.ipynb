# %%
import numpy as np
import pandas as pd 
import sklearn
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
import os
for dirname,_,filenames in os.walk('/kaggle/input'):
    print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('C:/Users/maity/OneDrive/Desktop/Apathy/crudeoil.csv')

# %%
df = df.rename(columns={'change': 'dollarChange'})
df['date'] = pd.to_datetime(df['date']).dt.date
df
# Out:
#            date   price  percentChange  dollarChange
# 0    1983-03-30   29.27            NaN           NaN
# 1    1983-04-04   30.63       4.646396          1.36
# 2    1983-05-02   30.25      -1.240614         -0.38
# 3    1983-06-01   31.38       3.735537          1.13
# 4    1983-07-01   32.00       1.975781          0.62
# ..          ...     ...            ...           ...
# 464  2021-11-01   65.85     -19.479090        -15.93
# 465  2021-12-01   74.88      13.712984          9.03
# 466  2022-01-03   86.49      15.504808         11.61
# 467  2022-02-01   95.72      10.671754          9.23
# 468  2022-03-01  109.33      14.218554         13.61
#
# [469 rows x 4 columns]

# %%
plt.plot(df['date'],df['price'])
plt.title('Oil Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.plot(df['date'], df['price'])
plt.title('Oil Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
df['6DayAverage'] = df['price'].rolling(6).mean()
df['11DayAverage'] = df['price'].rolling(11).mean()
df['16DayAverage'] = df['price'].rolling(16).mean()
df['running_total'] = df['dollarChange'].cumsum()
df = df.dropna()
df = df.iloc[-104:]
df
# Out:
#            date   price  percentChange  dollarChange  6DayAverage  \
# 365  2013-08-01  107.65       2.494525          2.62    98.650000
# 366  2013-09-03  102.33      -4.941941         -5.32    99.500000
# 367  2013-10-01   96.38      -5.814522         -5.95    99.986667
# 368  2013-11-01   92.72      -3.797468         -3.66   100.111667
# 369  2013-12-02   98.42       6.147541          5.70   100.421667
# ..          ...     ...            ...           ...          ...
# 464  2021-11-01   65.85     -19.479090        -15.93    73.096667
# 465  2021-12-01   74.88      13.712984          9.03    73.331667
# 466  2022-01-03   86.49      15.504808         11.61    75.421667
# 467  2022-02-01   95.72      10.671754          9.23    79.958333
# 468  2022-03-01  109.33      14.218554         13.61    85.675000
#
#      11DayAverage  16DayAverage  running_total
# 365     95.310000     93.538750          78.38
# 366     96.772727     94.526250          73.06
# ...

# %%
plt.plot(df['date'], df['momentum'], label = "momentum")
plt.legend(loc="upper left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'momentum'
#
# The above exception was the direct cause of the following exception:
#
# ...
